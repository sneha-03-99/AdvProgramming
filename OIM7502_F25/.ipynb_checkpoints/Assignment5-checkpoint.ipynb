# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv('data/homes.csv')
df = df.sort_values(by='Sell', ascending=True)
df.head()
# Out:
#    Sell   List  Living  Rooms  Beds  Baths   Age  Acres   Taxes
# 50         NaN     NaN    NaN   NaN    NaN   NaN    NaN     NaN
# 13  106  116.0    20.0    8.0   4.0    1.0  13.0   0.22  2818.0
# 41  110  120.0    15.0    8.0   4.0    2.0  11.0   0.59  3119.0
# 26  110  115.0    16.0    8.0   4.0    1.0  26.0   0.29  3103.0
# 48  111  120.0    15.0    8.0   3.0    1.0  97.0   1.11  3205.0

# %% [markdown]
# We begin by importing the pandas library and reading the homes.csv file into a DataFrame called df. The head() function shows the first five rows, giving an initial view of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 50 to 9
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sell    51 non-null     object
#  1   List    50 non-null     float64
#  2   Living  50 non-null     float64
#  3   Rooms   50 non-null     float64
#  4   Beds    50 non-null     float64
#  5   Baths   50 non-null     float64
#  6   Age     50 non-null     float64
#  7   Acres   50 non-null     float64
#  8   Taxes   50 non-null     float64
# dtypes: float64(8), object(1)
# memory usage: 4.0+ KB

# %% [markdown]
# The info() function displays the column names, data types, and non-null values — helping us understand the structure and completeness of the dataset.

# %%
df.describe()
# Out:
#              List     Living      Rooms       Beds      Baths         Age  \
# count   50.000000  50.000000  50.000000  50.000000  50.000000   50.000000
# mean   178.340000  21.120000   8.060000   3.820000   1.860000   30.220000
# std     79.382723   8.351072   1.284285   0.690755   0.756199   30.962314
# min     90.000000  10.000000   5.000000   3.000000   1.000000    2.000000
# 25%    140.000000  17.000000   7.000000   3.000000   1.000000   12.250000
# 50%    160.000000  20.000000   8.000000   4.000000   2.000000   24.500000
# 75%    190.000000  22.750000   9.000000   4.000000   2.000000   37.000000
# max    625.000000  64.000000  12.000000   6.000000   4.000000  202.000000
#
#            Acres         Taxes
# count  50.000000     50.000000
# mean    1.020600   3706.100000
# std     1.191496   1579.915268
# min     0.220000   1445.000000
# 25%     0.382500   3107.000000
# 50%     0.550000   3490.000000
# 75%     1.182500   3919.250000
# max     6.490000  12192.000000

# %% [markdown]
# The describe() function provides key statistics such as mean, median, and standard deviation for each numeric variable, giving insights into their distributions.

# %%
df.isnull().sum()
# Out:
# Sell      0
# List      1
# Living    1
# Rooms     1
# Beds      1
# Baths     1
# Age       1
# Acres     1
# Taxes     1
# dtype: int64

# %% [markdown]
# Checking for missing values ensures data completeness. If any columns have many missing values, we may need to handle them before analysis.

# %%
df = df.dropna()

# %% [markdown]
# To handle the missing values we use the dropna() function. It removes every row that has atleast one NaN(missing) value in any column.

# %%
plt.hist(df['Sell'], bins=20, color='skyblue', edgecolor='black', rwidth=0.9)
plt.title('Distribution of Home Selling Prices')
plt.xlabel('Selling Price')
plt.ylabel('Frequency')
plt.xticks(plt.xticks()[0][::2],rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The histogram shows how selling prices are distributed — whether they are normally distributed or skewed. This helps understand data spread and potential outliers.

# %%
plt.figure(figsize=(10, 8))
plt.scatter(df['Taxes'], df['Sell'], color='orange')
plt.title('Relationship between Taxes and Selling Price')
plt.xlabel('Taxes')
plt.ylabel('Selling Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# We use the LinearRegression model from sklearn to predict Sell based on Taxes.

# %%
X = df[['Taxes']]  # independent variable
y = df['Sell'] 
model = LinearRegression()
model.fit(X, y)
print("Intercept:", model.intercept_)
print("Coefficient for Taxes:", model.coef_[0])
print("R-squared:", model.score(X, y))
# Out:
# Intercept: 16.87187910246172
# Coefficient for Taxes: 0.04141499713918629
# R-squared: 0.8088101825924694

# %% [markdown]
#     •Intercept represents the baseline selling price when taxes are zero.
# 	•	Coefficient shows how much selling price increases for every unit increase in taxes.
# 	•	R-squared measures how well the model explains the variation in selling price (closer to 1 means a better fit).
#     If R² is low, taxes alone may not be a strong predictor of selling price.

# %%
plt.figure(figsize=(10, 8))
plt.scatter(df['Acres'], df['Sell'], color='red')
plt.title('Relationship between Acres and Selling Price')
plt.xlabel('Acres')
plt.ylabel('Selling Price')
plt.tight_layout()
plt.show()

X1 = df[['Acres']]  # independent variable
y1 = df['Sell'] 
model = LinearRegression()
model.fit(X1, y1)
print("Intercept:", model.intercept_)
print("Coefficient for Acres:", model.coef_[0])
print("R-squared:", model.score(X1, y1))
# Out:
# Intercept: 159.84568771298711
# Coefficient for Acres: 10.302089248493917
# R-squared: 0.028464240147957898

# %% [markdown]
# When comparing the two models, based on teh R-squared coefficients we can understand that taxes and Selling price have a higher correlation whereas the Acres and selling price have a weaker relationship. Also for the first one its easier to see a clear upward line through the scatter plot which isnt the same for the second plot.

# %% [markdown]
# 	•	Simple linear regression only measures the impact of one variable at a time.
# 	•	Real-world house prices depend on many interacting factors such as neighborhood, size, and age.
# 	•	Outliers can distort the regression line.
# 	•	Correlation ≠ causation — just because taxes correlate with price doesn’t mean one causes the other
