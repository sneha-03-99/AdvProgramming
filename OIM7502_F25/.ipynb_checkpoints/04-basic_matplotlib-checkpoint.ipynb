# %% [markdown]
# ## Basic Graphing with matplotlib
# * Line graph
# * Histogram
# * Scatter plot

# %% [markdown]
# ### Libraries we will be using
# * pep 8 (style guide for Python) suggests these should be in alphabetical order

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal as n
from scipy.stats import norm

# %% [markdown]
# ### Initialization of variable for simulating security price

# %%
r = .0525
T = 1/252
sigma = .30
aapl = 254
prices = list()

# %% [markdown]
# ### Simulation of one possible price path for an arbitrary quarter

# %%
for day in range(63):
    prices.append(aapl)
    aapl*= np.exp((r - .5 * sigma**2) *T+ sigma * np.sqrt(T) * n(0,1))
prices
#diff from class
# Out:
# [254,
#  np.float64(245.24442625672717),
#  np.float64(245.07374050588987),
#  np.float64(248.30637658121273),
#  np.float64(250.98536526079573),
#  np.float64(243.20225989507742),
#  np.float64(240.58056836476754),
#  np.float64(237.04037598127042),
#  np.float64(235.43155443577834),
#  np.float64(229.56704798936457),
#  np.float64(226.3477807561325),
#  np.float64(223.86398149569422),
#  np.float64(222.92845176842704),
#  np.float64(219.5395377388071),
#  np.float64(222.20117160277675),
#  np.float64(219.61981979327058),
#  np.float64(218.48656208059333),
#  np.float64(217.59512188921113),
#  np.float64(220.7897319482013),
#  np.float64(217.91732576453748),
#  np.float64(217.57284777816267),
#  np.float64(223.5327453136649),
#  np.float64(225.24309692735753),
#  np.float64(224.32580268567165),
#  np.float64(226.02089644416068),
#  np.float64(226.66459394854994),
#  np.float64(232.9747213713769),
#  np.float64(237.53205074832186),
#  np.float64(237.90920617265922),
#  np.float64(236.80965747990584),
#  np.float64(241.17568093038508),
#  np.float64(238.01614837520717),
#  np.float64(237.16936352972326),
#  np.float64(238.3863546250675),
#  np.float64(237.37305976246438),
#  np.float64(236.7151489307462),
#  np.float64(245.3807684003727),
#  np.float64(243.93132056139277),
#  np.float64(239.2230345728357),
#  np.float64(240.48121514085258),
#  np.float64(244.27220821610345),
#  np.float64(244.06527393606873),
#  np.float64(248.85561328675294),
#  np.float64(246.9154010695024),
#  np.float64(232.06620456556814),
#  np.float64(231.41659910775635),
#  np.float64(235.28276107257318),
#  np.float64(238.80581793250207),
#  np.float64(232.088430544549),
#  np.float64(234.61583708041243),
#  np.float64(232.20987472195546),
#  np.float64(229.329016623827),
#  np.float64(231.1001276311278),
#  np.float64(232.96210303119656),
#  np.float64(230.48982742440253),
#  np.float64(233.63400177584404),
#  np.float64(231.98904335530617),
#  np.float64(232.84736155850163),
#  np.float64(232.37594856897456),
#  np.float64(231.5472843735362),
#  np.float64(235.41618214978376),
#  np.float64(236.87578342837273),
#  np.float64(236.60603846161092),
#  np.float64(235.75733353992123),
#  np.float64(234.17075498811406),
#  np.float64(242.04394092543646),
#  np.float64(244.1851272670671),
#  np.float64(238.4411851076232),
#  np.float64(234.41611841125055),
#  np.float64(234.1982785795925),
#  np.float64(233.49132528882998),
#  np.float64(227.7198247527343),
#  np.float64(229.6551721304238),
#  np.float64(230.67701098319677),
#  np.float64(230.7980399500399),
#  np.float64(228.09051796910143),
#  np.float64(233.02198257248202),
#  np.float64(233.79778207587378),
#  np.float64(234.2399926150263),
#  np.float64(228.34904036885854),
#  np.float64(229.59499255004368),
#  np.float64(232.53630102595272),
#  np.float64(233.32397475861745),
#  np.float64(236.42983176800803),
#  np.float64(236.08686781764115),
#  np.float64(231.99951826917922),
#  np.float64(226.18796196123893),
#  np.float64(232.05686032605817),
#  np.float64(232.58676185661633),
#  np.float64(242.4129870248641),
#  np.float64(245.76957000009133),
#  np.float64(234.22645477679572),
#  np.float64(231.1209383772893),
#  np.float64(230.6065206037614),
#  np.float64(237.16217203930847),
#  np.float64(236.29758734490161),
#  np.float64(236.49318920302593),
#  np.float64(233.89746111701203),
#  np.float64(229.07829171078677),
#  np.float64(232.69532299461247),
#  np.float64(231.42417083854272),
#  np.float64(235.79948299222065),
#  np.float64(230.7685504414016),
#  np.float64(224.43312905942236),
#  np.float64(219.48950162763597),
#  np.float64(222.6733061699204),
#  np.float64(222.7559614395236),
#  np.float64(215.66392121438994),
#  np.float64(213.5932451985718),
#  np.float64(205.11125175312984),
#  np.float64(207.51406390380913),
#  np.float64(203.37312155188644),
#  np.float64(201.51065430461912),
#  np.float64(202.63738651073234),
#  np.float64(197.88420043830274),
#  np.float64(197.9521449524335),
#  np.float64(200.71437393353187),
#  np.float64(192.13541027671016),
#  np.float64(195.55030689686126),
#  np.float64(191.39731870821154),
#  np.float64(189.47641182243635),
#  np.float64(191.19120816718845),
#  np.float64(198.09238583484748),
#  np.float64(197.65104992903332),
#  np.float64(202.8537744226659),
#  np.float64(208.0614635038223)]

# %%
len(prices)
# Out:
# 63

# %% [markdown]
# ### The plot method takes one or two variables and generates a line plot
# * there are a long list of methods to augment and annotate your plots
# * The semicolon surpresses entraneous output in the notebook setting

# %%
plt.plot(prices, color='r', ls='--' );

# %% [markdown]
# ### Simulation of 5000 possible paths
# * reset the price variable before running

# %%
for iter in range(5000):
    aapl=254
    prices.append([])
    for day in range(63):
        prices[iter].append(aapl)
        aapl*= np.exp((r - .5 * sigma**2) *T+ sigma * np.sqrt(T) * n(0,1))

# %%
plt.plot(prices, color='r', ls='--' );

# %% [markdown]
# ### Plot the first 10 paths
# * as you can see it is easy to plot many lines on the same graph
# * everyt time you use `plt.` it effects the current plot

# %%
for path in range(10):
#range in prices[10:20]
    plt.plot(prices[path])
plt.grid(axis='y',alpha =0.3)

# %%
plt.plot(prices[:3], color='r', ls='--' );

# %% [markdown]
# ### Peel off the last value in each path and store in a new variable

# %%
ending= list()
for row in range(5000):
    ending.append(prices[row][-1])

# %%
plt.boxplot(ending);

# %% [markdown]
# ### Let's make a histogram of each path's ending price!
# * plot data
# * overlay a theoretical normal curve based on scipy normal model to see how the data fits
# * Since a stocks price in the future generally reflects a lognormal ditribution, the overlay is more open-ended on the left

# %%
plt.hist(ending, bins =25,density =True, edgecolor='w')
x = np.linspace(min(ending), max(ending))
mean, std = norm.fit(ending)
pdf = norm.pdf(x, mean, std)
plt.plot(x, pdf)


;
# Out:
# ''

# %% [markdown]
# ### Using Seaborn to generate a simple histogram
# * the kde (kernel density estimate) is not quite the thing as the previous normal overlay

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# ### Using NumPy to fit a simple regression model

# %% [markdown]
# ### Assign the output of the model to appropriate variables

# %% [markdown]
# ### Plot the original data and least squares (regression) line

# %% [markdown]
# ### When generating random numbers it is sometime preferable to generate a constant stream
# * This can be done by creating a default generator
# * Often this is referred to as the random seed

# %% [markdown]
# ### There is a so-called object-oriented method of using matplotlib
# * This involves assigning variables for two matplotlib objects
# * These variables are commonly called fig and ax or axes
# * This methodology may allow greater control over your output
# * There are syntactic differences when using this method

# %% [markdown]
# ### Your work can be saved out to typical image formats (.png, .jpg)
